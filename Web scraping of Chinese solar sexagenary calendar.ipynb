# %% [markdown]
# ## 1. Background

# %% [markdown]
# Chinese numerology, or bazi, is a common cultural practice used by many Chinese for date selection and character profiling. Every year, month, day and hour is represented by a pillar, which is combination of a Heavenly Stem (base-10) and the Earthly Branch (base-12) character. The respective pillars can be found in the Chinese solar sexagenary calendar. Every stem and branch represents certain elements, and the interaction of all the elements present at a particular time is used to predict the outcomes of events.
#
# To convert a date from the Gregorian calendar to the Chinese solar sexagenary calendar, a book called *Tung Shing* (通勝) is used. The *Tung Shing* also contains description of the suitable activities of the day, which many fengshui practioners and geomancers use.

# %% [markdown]
# ## 2. Problem statement

# %% [markdown]
# While there are free websites and apps that provides information for individual dates, the ability to extract multiple dates fulfiling one or more criteria is usually not available, or only found on the paid tier. In this project, we are going to create a digital database containing some basic information of the *Tong Shing*, which can queried and searched using SQL language.

# %% [markdown]
# ## 3. Dataset

# %% [markdown]
# We are going to use the open-source information found on [Wikibooks](https://en.wikibooks.org/wiki/Ba_Zi).

# %% [markdown]
# ## 4. Import dependencies

# %%
import pandas as pd
import requests
import numpy as np
import re

# %% [markdown]
# ## 5. Web scraping

# %% [markdown]
# ### 5.1. Scrape birth date table for all available years

# %% [markdown]
# #### 5.1.1. Send http request, receive html responses and convert html to list of dataframe objects

# %%
# %%time
lst_birth = []
for year in range(1902, 2049): #2049
    url = 'https://en.wikibooks.org/wiki/Ba_Zi/Yr' + str(year)
    html = requests.get(url, timeout = 5, verify = True)
    dfs = pd.read_html(html.text)
    for x in dfs:
        lst_birth.append(x)
len(lst_birth)
# Out:
# Wall time: 29 s
# 1764

# %%
#checking results for 2 months 
lst_birth[0:2]
# Out:
# [    S/N  Year  Month  Day  SS  Hour Pillar Day Pillar Month Pillar  \
#  0     1  1902      1    1  11   Time of H1      H1_E9        H7_E1
#  1     2  1902      1    2  11   Time of H2     H2_E10        H7_E1
#  2     3  1902      1    3  11   Time of H3     H3_E11        H7_E1
#  3     4  1902      1    4  11   Time of H4     H4_E12        H7_E1
#  4     5  1902      1    5  11   Time of H5      H5_E1        H7_E1
#  5     6  1902      1    6  12   Time of H6      H6_E2        H8_E2
#  6     7  1902      1    7  12   Time of H7      H7_E3        H8_E2
#  7     8  1902      1    8  12   Time of H8      H8_E4        H8_E2
#  8     9  1902      1    9  12   Time of H9      H9_E5        H8_E2
#  9    10  1902      1   10  12  Time of H10     H10_E6        H8_E2
#  10   11  1902      1   11  12   Time of H1      H1_E7        H8_E2
#  11   12  1902      1   12  12   Time of H2      H2_E8        H8_E2
#  12   13  1902      1   13  12   Time of H3      H3_E9        H8_E2
#  13   14  1902      1   14  12   Time of H4     H4_E10        H8_E2
#  14   15  1902      1   15  12   Time of H5     H5_E11        H8_E2
#  15   16  1902      1   16  12   Time of H6     H6_E12        H8_E2
#  16   17  1902      1   17  12   Time of H7      H7_E1        H8_E2
#  17   18  1902      1   18  12   Time of H8      H8_E2        H8_E2
#  18   19  1902      1   19  12   Time of H9      H9_E3        H8_E2
#  19   20  1902      1   20  12  Time of H10     H10_E4        H8_E2
#  20   21  1902      1   21  12   Time of H1      H1_E5        H8_E2
#  21   22  1902      1   22  12   Time of H2      H2_E6        H8_E2
#  22   23  1902      1   23  12   Time of H3      H3_E7        H8_E2
#  23   24  1902      1   24  12   Time of H4      H4_E8        H8_E2
#  24   25  1902      1   25  12   Time of H5      H5_E9        H8_E2
#  25   26  1902      1   26  12   Time of H6     H6_E10        H8_E2
#  26   27  1902      1   27  12   Time of H7     H7_E11        H8_E2
#  27   28  1902      1   28  12   Time of H8     H8_E12        H8_E2
#  28   29  1902      1   29  12   Time of H9      H9_E1        H8_E2
#  29   30  1902      1   30  12  Time of H10     H10_E2        H8_E2
#  30   31  1902      1   31  12   Time of H1      H1_E3        H8_E2
#
#     Year Pillar Male Luck Pillar Female Luck Pillar
#  0        H8_E2   Age 8 (H6E12r)      Age 2 (H8E2f)
#  1        H8_E2   Age 9 (H6E12r)      Age 1 (H8E2f)
#  2        H8_E2   Age 9 (H6E12r)      Age 1 (H8E2f)
#  3        H8_E2   Age 9 (H6E12r)      Age 1 (H8E2f)
#  4        H8_E2  Age 10 (H6E12r)      Age 0 (H8E2f)
#  5        H8_E2    Age 0 (H7E1r)     Age 10 (H9E3f)
#  6        H8_E2    Age 1 (H7E1r)     Age 10 (H9E3f)
#  7        H8_E2    Age 1 (H7E1r)      Age 9 (H9E3f)
#  8        H8_E2    Age 1 (H7E1r)      Age 9 (H9E3f)
#  9        H8_E2    Age 2 (H7E1r)      Age 9 (H9E3f)
#  10       H8_E2    Age 2 (H7E1r)      Age 8 (H9E3f)
#  11       H8_E2    Age 2 (H7E1r)      Age 8 (H9E3f)
#  12       H8_E2    Age 3 (H7E1r)      Age 8 (H9E3f)
#  13       H8_E2    Age 3 (H7E1r)      Age 7 (H9E3f)
#  14       H8_E2    Age 3 (H7E1r)      Age 7 (H9E3f)
#  15       H8_E2    Age 4 (H7E1r)      Age 7 (H9E3f)
#  16       H8_E2    Age 4 (H7E1r)      Age 6 (H9E3f)
#  17       H8_E2    Age 4 (H7E1r)      Age 6 (H9E3f)
#  18       H8_E2    Age 5 (H7E1r)      Age 6 (H9E3f)
#  19       H8_E2    Age 5 (H7E1r)      Age 5 (H9E3f)
#  20       H8_E2    Age 5 (H7E1r)      Age 5 (H9E3f)
#  21       H8_E2    Age 6 (H7E1r)      Age 5 (H9E3f)
#  22       H8_E2    Age 6 (H7E1r)      Age 4 (H9E3f)
#  23       H8_E2    Age 6 (H7E1r)      Age 4 (H9E3f)
#  24       H8_E2    Age 7 (H7E1r)      Age 4 (H9E3f)
#  25       H8_E2    Age 7 (H7E1r)      Age 3 (H9E3f)
#  26       H8_E2    Age 7 (H7E1r)      Age 3 (H9E3f)
#  27       H8_E2    Age 8 (H7E1r)      Age 3 (H9E3f)
#  28       H8_E2    Age 8 (H7E1r)      Age 2 (H9E3f)
#  29       H8_E2    Age 8 (H7E1r)      Age 2 (H9E3f)
#  30       H8_E2    Age 9 (H7E1r)      Age 2 (H9E3f)  ,
#      S/N  Year  Month  Day  SS  Hour Pillar Day Pillar Month Pillar  \
#  0    32  1902      2    1  12   Time of H2      H2_E4        H8_E2
#  1    33  1902      2    2  12   Time of H3      H3_E5        H8_E2
#  2    34  1902      2    3  12   Time of H4      H4_E6        H8_E2
#  3    35  1902      2    4  12   Time of H5      H5_E7        H8_E2
#  4    36  1902      2    5   1   Time of H6      H6_E8        H9_E3
#  5    37  1902      2    6   1   Time of H7      H7_E9        H9_E3
#  6    38  1902      2    7   1   Time of H8     H8_E10        H9_E3
#  7    39  1902      2    8   1   Time of H9     H9_E11        H9_E3
#  8    40  1902      2    9   1  Time of H10    H10_E12        H9_E3
#  9    41  1902      2   10   1   Time of H1      H1_E1        H9_E3
#  10   42  1902      2   11   1   Time of H2      H2_E2        H9_E3
#  11   43  1902      2   12   1   Time of H3      H3_E3        H9_E3
#  12   44  1902      2   13   1   Time of H4      H4_E4        H9_E3
#  13   45  1902      2   14   1   Time of H5      H5_E5        H9_E3
#  14   46  1902      2   15   1   Time of H6      H6_E6        H9_E3
#  15   47  1902      2   16   1   Time of H7      H7_E7        H9_E3
#  16   48  1902      2   17   1   Time of H8      H8_E8        H9_E3
#  17   49  1902      2   18   1   Time of H9      H9_E9        H9_E3
#  18   50  1902      2   19   1  Time of H10    H10_E10        H9_E3
#  19   51  1902      2   20   1   Time of H1     H1_E11        H9_E3
#  20   52  1902      2   21   1   Time of H2     H2_E12        H9_E3
#  21   53  1902      2   22   1   Time of H3      H3_E1        H9_E3
#  22   54  1902      2   23   1   Time of H4      H4_E2        H9_E3
#  23   55  1902      2   24   1   Time of H5      H5_E3        H9_E3
#  24   56  1902      2   25   1   Time of H6      H6_E4        H9_E3
#  25   57  1902      2   26   1   Time of H7      H7_E5        H9_E3
#  26   58  1902      2   27   1   Time of H8      H8_E6        H9_E3
#  27   59  1902      2   28   1   Time of H9      H9_E7        H9_E3
#
#     Year Pillar Male Luck Pillar Female Luck Pillar
#  0        H8_E2    Age 9 (H7E1r)      Age 1 (H9E3f)
#  1        H8_E2    Age 9 (H7E1r)      Age 1 (H9E3f)
#  2        H8_E2   Age 10 (H7E1r)      Age 1 (H9E3f)
#  3        H8_E2   Age 10 (H7E1r)      Age 0 (H9E3f)
#  4        H9_E3  Age 10 (H10E4f)      Age 0 (H8E2r)
#  5        H9_E3   Age 9 (H10E4f)      Age 1 (H8E2r)
#  6        H9_E3   Age 9 (H10E4f)      Age 1 (H8E2r)
#  7        H9_E3   Age 9 (H10E4f)      Age 1 (H8E2r)
#  8        H9_E3   Age 8 (H10E4f)      Age 2 (H8E2r)
#  9        H9_E3   Age 8 (H10E4f)      Age 2 (H8E2r)
#  10       H9_E3   Age 8 (H10E4f)      Age 2 (H8E2r)
#  11       H9_E3   Age 7 (H10E4f)      Age 3 (H8E2r)
#  12       H9_E3   Age 7 (H10E4f)      Age 3 (H8E2r)
#  13       H9_E3   Age 7 (H10E4f)      Age 3 (H8E2r)
#  14       H9_E3   Age 6 (H10E4f)      Age 4 (H8E2r)
#  15       H9_E3   Age 6 (H10E4f)      Age 4 (H8E2r)
#  16       H9_E3   Age 6 (H10E4f)      Age 4 (H8E2r)
#  17       H9_E3   Age 5 (H10E4f)      Age 5 (H8E2r)
#  18       H9_E3   Age 5 (H10E4f)      Age 5 (H8E2r)
#  19       H9_E3   Age 5 (H10E4f)      Age 5 (H8E2r)
#  20       H9_E3   Age 4 (H10E4f)      Age 6 (H8E2r)
#  21       H9_E3   Age 4 (H10E4f)      Age 6 (H8E2r)
#  22       H9_E3   Age 4 (H10E4f)      Age 6 (H8E2r)
#  23       H9_E3   Age 3 (H10E4f)      Age 7 (H8E2r)
#  24       H9_E3   Age 3 (H10E4f)      Age 7 (H8E2r)
#  25       H9_E3   Age 3 (H10E4f)      Age 7 (H8E2r)
#  26       H9_E3   Age 2 (H10E4f)      Age 8 (H8E2r)
#  27       H9_E3   Age 2 (H10E4f)      Age 8 (H8E2r)  ]

# %% [markdown]
# #### 5.1.2. Merge all years into single dataframe

# %%
df_birth = pd.concat([x for x in lst_birth], axis = 0, ignore_index=True) #stack all 12 months of each year on top of each other
df_birth.head()
# Out:
#    S/N  Year  Month  Day  SS Hour Pillar Day Pillar Month Pillar Year Pillar  \
# 0    1  1902      1    1  11  Time of H1      H1_E9        H7_E1       H8_E2
# 1    2  1902      1    2  11  Time of H2     H2_E10        H7_E1       H8_E2
# 2    3  1902      1    3  11  Time of H3     H3_E11        H7_E1       H8_E2
# 3    4  1902      1    4  11  Time of H4     H4_E12        H7_E1       H8_E2
# 4    5  1902      1    5  11  Time of H5      H5_E1        H7_E1       H8_E2
#
#   Male Luck Pillar Female Luck Pillar
# 0   Age 8 (H6E12r)      Age 2 (H8E2f)
# 1   Age 9 (H6E12r)      Age 1 (H8E2f)
# 2   Age 9 (H6E12r)      Age 1 (H8E2f)
# 3   Age 9 (H6E12r)      Age 1 (H8E2f)
# 4  Age 10 (H6E12r)      Age 0 (H8E2f)

# %%
len(df_birth)
# Out:
# 53692

# %% [markdown]
# #### 5.1.3. Rename columns

# %%
df_birth.columns = df_birth.columns.str.lower()
df_birth.columns = df_birth.columns.str.replace(' ', '_')
df_birth.rename(columns={'SS': 'season' }, inplace=True)

df_birth.columns
# Out:
# Index(['s/n', 'year', 'month', 'day', 'ss', 'hour_pillar', 'day_pillar',
#        'month_pillar', 'year_pillar', 'male_luck_pillar',
#        'female_luck_pillar'],
#       dtype='object')

# %% [markdown]
# #### 5.1.4 Check for null values

# %%
df_birth.isnull().mean().sum()# no null values
# Out:
# 0.0

# %% [markdown]
# No null values in birth chart dataframe.

# %% [markdown]
# #### 5.1.5 Check for data types

# %%
df_birth.dtypes
# Out:
# s/n                    int64
# year                   int64
# month                  int64
# day                    int64
# ss                     int64
# hour_pillar           object
# day_pillar            object
# month_pillar          object
# year_pillar           object
# male_luck_pillar      object
# female_luck_pillar    object
# dtype: object

# %% [markdown]
# Date elements and order of season are in integers, while pillars are in object type (string).

# %% [markdown]
# #### 5.1.6. Expand year, month and day pillars to obtain stems and branches

# %% [markdown]
# To facilitate later SQL queries, we will expand the information that had been compressed into the pillars into new columns.

# %%
#expand year pillar
new = df_birth['year_pillar'].str.split('_', expand = True)
df_birth['year_stem'] = new[0]
df_birth['year_branch'] = new[1]

#expand month pillar
new = df_birth['month_pillar'].str.split('_', expand = True)
df_birth['mth_stem'] = new[0]
df_birth['mth_branch'] = new[1]

#expand day pillar
new = df_birth['day_pillar'].str.split('_', expand = True)
df_birth['day_stem'] = new[0]
df_birth['day_branch'] = new[1]

df_birth.head()
# Out:
#    s/n  year  month  day  ss hour_pillar day_pillar month_pillar year_pillar  \
# 0    1  1902      1    1  11  Time of H1      H1_E9        H7_E1       H8_E2
# 1    2  1902      1    2  11  Time of H2     H2_E10        H7_E1       H8_E2
# 2    3  1902      1    3  11  Time of H3     H3_E11        H7_E1       H8_E2
# 3    4  1902      1    4  11  Time of H4     H4_E12        H7_E1       H8_E2
# 4    5  1902      1    5  11  Time of H5      H5_E1        H7_E1       H8_E2
#
#   male_luck_pillar female_luck_pillar year_stem year_branch mth_stem  \
# 0   Age 8 (H6E12r)      Age 2 (H8E2f)        H8          E2       H7
# 1   Age 9 (H6E12r)      Age 1 (H8E2f)        H8          E2       H7
# 2   Age 9 (H6E12r)      Age 1 (H8E2f)        H8          E2       H7
# 3   Age 9 (H6E12r)      Age 1 (H8E2f)        H8          E2       H7
# 4  Age 10 (H6E12r)      Age 0 (H8E2f)        H8          E2       H7
#
#   mth_branch day_stem day_branch
# 0         E1       H1         E9
# 1         E1       H2        E10
# 2         E1       H3        E11
# 3         E1       H4        E12
# 4         E1       H5         E1

# %% [markdown]
# #### 5.1.7. Expand luck pillar

# %%
# %%time
def find_lp_stem(x):
    stem = re.search('H\d+', x)
    return stem.group()

def find_lp_branch(x):
    branch = re.search('E\d+', x)
    return branch.group()

df_birth['male_lp_age'] = df_birth['male_luck_pillar'].str.split(' ').map(lambda x: x[1])
df_birth['female_lp_age'] = df_birth['female_luck_pillar'].str.split(' ').map(lambda x: x[1])
df_birth['male_lp_dir'] = df_birth['male_luck_pillar'].str.split(' ').map(lambda x: x[2][-2])
df_birth['female_lp_dir'] = df_birth['female_luck_pillar'].str.split(' ').map(lambda x: x[2][-2])
df_birth['male_lp_pillar'] = df_birth['male_luck_pillar'].str.split(' ').map(lambda x: x[2][1:-2])
df_birth['female_lp_pillar'] = df_birth['female_luck_pillar'].str.split(' ').map(lambda x: x[2][1:-2])
df_birth['male_lp_stem'] = df_birth['male_luck_pillar'].map(lambda x: find_lp_stem(x))
df_birth['male_lp_branch'] = df_birth['male_luck_pillar'].map(lambda x: find_lp_branch(x))
df_birth['female_lp_stem'] = df_birth['female_luck_pillar'].map(lambda x: find_lp_stem(x))
df_birth['female_lp_branch'] = df_birth['female_luck_pillar'].map(lambda x: find_lp_branch(x))

# repopulate luck pillar with hour stem and branch
df_birth['male_lp_pillar'] = df_birth['male_lp_stem'] + '_' + df_birth['male_lp_branch']
df_birth['female_lp_pillar'] = df_birth['female_lp_stem'] + '_' + df_birth['female_lp_branch']

df_birth.head()
# Out:
# Wall time: 552 ms
#    s/n  year  month  day  ss hour_pillar day_pillar month_pillar year_pillar  \
# 0    1  1902      1    1  11  Time of H1      H1_E9        H7_E1       H8_E2
# 1    2  1902      1    2  11  Time of H2     H2_E10        H7_E1       H8_E2
# 2    3  1902      1    3  11  Time of H3     H3_E11        H7_E1       H8_E2
# 3    4  1902      1    4  11  Time of H4     H4_E12        H7_E1       H8_E2
# 4    5  1902      1    5  11  Time of H5      H5_E1        H7_E1       H8_E2
#
#   male_luck_pillar  ... male_lp_age female_lp_age male_lp_dir female_lp_dir  \
# 0   Age 8 (H6E12r)  ...           8             2           r             f
# 1   Age 9 (H6E12r)  ...           9             1           r             f
# 2   Age 9 (H6E12r)  ...           9             1           r             f
# 3   Age 9 (H6E12r)  ...           9             1           r             f
# 4  Age 10 (H6E12r)  ...          10             0           r             f
#
#   male_lp_pillar female_lp_pillar male_lp_stem male_lp_branch female_lp_stem  \
# 0         H6_E12            H8_E2           H6            E12             H8
# 1         H6_E12            H8_E2           H6            E12             H8
# 2         H6_E12            H8_E2           H6            E12             H8
# 3         H6_E12            H8_E2           H6            E12             H8
# 4         H6_E12            H8_E2           H6            E12             H8
#
#   female_lp_branch
# 0               E2
# 1               E2
# 2               E2
# 3               E2
# 4               E2
#
# [5 rows x 27 columns]

# %% [markdown]
# #### 5.1.8. Drop irrelevant columns from birth date table

# %%
df_birth = df_birth.drop(columns = ['s/n', 'male_luck_pillar','female_luck_pillar', 'hour_pillar'])
# check final columns
df_birth.columns
# Out:
# Index(['year', 'month', 'day', 'ss', 'day_pillar', 'month_pillar',
#        'year_pillar', 'year_stem', 'year_branch', 'mth_stem', 'mth_branch',
#        'day_stem', 'day_branch', 'male_lp_age', 'female_lp_age', 'male_lp_dir',
#        'female_lp_dir', 'male_lp_pillar', 'female_lp_pillar', 'male_lp_stem',
#        'male_lp_branch', 'female_lp_stem', 'female_lp_branch'],
#       dtype='object')

# %%
# Check final form of birth date table
df_birth.head()
# Out:
#    year  month  day  ss day_pillar month_pillar year_pillar year_stem  \
# 0  1902      1    1  11      H1_E9        H7_E1       H8_E2        H8
# 1  1902      1    2  11     H2_E10        H7_E1       H8_E2        H8
# 2  1902      1    3  11     H3_E11        H7_E1       H8_E2        H8
# 3  1902      1    4  11     H4_E12        H7_E1       H8_E2        H8
# 4  1902      1    5  11      H5_E1        H7_E1       H8_E2        H8
#
#   year_branch mth_stem  ... male_lp_age female_lp_age male_lp_dir  \
# 0          E2       H7  ...           8             2           r
# 1          E2       H7  ...           9             1           r
# 2          E2       H7  ...           9             1           r
# 3          E2       H7  ...           9             1           r
# 4          E2       H7  ...          10             0           r
#
#   female_lp_dir male_lp_pillar female_lp_pillar male_lp_stem male_lp_branch  \
# 0             f         H6_E12            H8_E2           H6            E12
# 1             f         H6_E12            H8_E2           H6            E12
# 2             f         H6_E12            H8_E2           H6            E12
# 3             f         H6_E12            H8_E2           H6            E12
# 4             f         H6_E12            H8_E2           H6            E12
#
#   female_lp_stem female_lp_branch
# 0             H8               E2
# 1             H8               E2
# 2             H8               E2
# 3             H8               E2
# 4             H8               E2
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 5.2. Scrape table on hour pillar calculation

# %% [markdown]
# #### 5.2.1. Send http request, receive html responses and convert html to dataframe

# %%
# %%time
url_hour = 'https://en.wikibooks.org/wiki/Ba_Zi/Hour_Pillar'
html = requests.get(url_hour, timeout = 5, verify = True)
df_hour = pd.read_html(html.text)
df_hour = df_hour[0]
df_hour
# Out:
# Wall time: 35.3 ms
#    Heavenly Stem of Day Pillar versus Time of Birth(时辰)   H1   H2   H3   H4  \
# 0                                            11pm-1am     H1   H3   H5   H7
# 1                                             1am-3am     H2   H4   H6   H8
# 2                                             3am-5am     H3   H5   H7   H9
# 3                                             5am-7am     H4   H6   H8  H10
# 4                                             7am-9am     H5   H7   H9   H1
# 5                                            9am-11am     H6   H8  H10   H2
# 6                                            11am-1pm     H7   H9   H1   H3
# 7                                             1pm-3pm     H8  H10   H2   H4
# 8                                             3pm-5pm     H9   H1   H3   H5
# 9                                             5pm-7pm    H10   H2   H4   H6
# 10                                            7pm-9pm     H1   H3   H5   H7
# 11                                           9pm-11pm     H2   H4   H6   H8
#
#      H5   H6   H7   H8   H9  H10 Earthly Branch ofHour Pillar
# 0    H9   H1   H3   H5   H7   H9                           E1
# 1   H10   H2   H4   H6   H8  H10                           E2
# 2    H1   H3   H5   H7   H9   H1                           E3
# 3    H2   H4   H6   H8  H10   H2                           E4
# 4    H3   H5   H7   H9   H1   H3                           E5
# 5    H4   H6   H8  H10   H2   H4                           E6
# 6    H5   H7   H9   H1   H3   H5                           E7
# 7    H6   H8  H10   H2   H4   H6                           E8
# 8    H7   H9   H1   H3   H5   H7                           E9
# 9    H8  H10   H2   H4   H6   H8                          E10
# 10   H9   H1   H3   H5   H7   H9                          E11
# 11  H10   H2   H4   H6   H8  H10                          E12

# %% [markdown]
# #### 5.2.2. Rename columns

# %%
df_hour.rename(columns={'Heavenly Stem of Day Pillar versus Time of Birth(时辰)': 'hour_range', 'Earthly Branch ofHour Pillar': 'hour_branch'}, inplace=True)
df_hour.head()
# Out:
#   hour_range  H1  H2  H3   H4   H5  H6  H7  H8   H9  H10 hour_branch
# 0   11pm-1am  H1  H3  H5   H7   H9  H1  H3  H5   H7   H9          E1
# 1    1am-3am  H2  H4  H6   H8  H10  H2  H4  H6   H8  H10          E2
# 2    3am-5am  H3  H5  H7   H9   H1  H3  H5  H7   H9   H1          E3
# 3    5am-7am  H4  H6  H8  H10   H2  H4  H6  H8  H10   H2          E4
# 4    7am-9am  H5  H7  H9   H1   H3  H5  H7  H9   H1   H3          E5

# %% [markdown]
# #### 5.2.3. Add hour_pair column

# %% [markdown]
# We will add an hour_pair value in lieu of the hour_range, for ease of locating the correct hour branch when calculating the hour pillar.

# %%
df_hour['hour_pair'] = df_hour.index + 1
df_hour.head()
# Out:
#   hour_range  H1  H2  H3   H4   H5  H6  H7  H8   H9  H10 hour_branch  \
# 0   11pm-1am  H1  H3  H5   H7   H9  H1  H3  H5   H7   H9          E1
# 1    1am-3am  H2  H4  H6   H8  H10  H2  H4  H6   H8  H10          E2
# 2    3am-5am  H3  H5  H7   H9   H1  H3  H5  H7   H9   H1          E3
# 3    5am-7am  H4  H6  H8  H10   H2  H4  H6  H8  H10   H2          E4
# 4    7am-9am  H5  H7  H9   H1   H3  H5  H7  H9   H1   H3          E5
#
#    hour_pair
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %% [markdown]
# #### 5.2.4. Drop irrelevant columns

# %%
df_hour.drop(columns = 'hour_range', inplace = True)
df_hour.head()
# Out:
#    H1  H2  H3   H4   H5  H6  H7  H8   H9  H10 hour_branch  hour_pair
# 0  H1  H3  H5   H7   H9  H1  H3  H5   H7   H9          E1          1
# 1  H2  H4  H6   H8  H10  H2  H4  H6   H8  H10          E2          2
# 2  H3  H5  H7   H9   H1  H3  H5  H7   H9   H1          E3          3
# 3  H4  H6  H8  H10   H2  H4  H6  H8  H10   H2          E4          4
# 4  H5  H7  H9   H1   H3  H5  H7  H9   H1   H3          E5          5

# %% [markdown]
# #### 5.2.5. Check data types

# %%
df_hour.dtypes
# Out:
# H1             object
# H2             object
# H3             object
# H4             object
# H5             object
# H6             object
# H7             object
# H8             object
# H9             object
# H10            object
# hour_branch    object
# hour_pair       int64
# dtype: object

# %% [markdown]
# All stems and branches are object type (string) except for the hour_pair, which is rightly an integer.

# %% [markdown]
# ### 5.3. Scrape table on elements in earthly branches
#
# Each Earthly Branch in the four Pillars will have one or more Heavenly Stems.

# %% [markdown]
# #### 5.3.1. Send http request, receive html responses and convert html to dataframe

# %%
# %%time
url_elm = 'https://en.wikibooks.org/wiki/Ba_Zi/Hidden_Stems'
html = requests.get(url_elm, timeout = 5, verify = True)
df_elm = pd.read_html(html.text)
# Out:
# Wall time: 32.8 ms

# %%
df_elm = df_elm[0]
df_elm
# Out:
#    Earthly Branchin anyPillar Hidden Heavenly Stems
# 0                          E3            H5, H1, H3
# 1                          E4                    H2
# 2                          E5           H10, H5, H2
# 3                          E6            H7, H3, H5
# 4                          E7                H4, H6
# 5                          E8            H4, H6, H2
# 6                          E9            H5, H7, H9
# 7                         E10                    H8
# 8                         E11            H4, H5, H8
# 9                         E12                H9, H1
# 10                         E1                   H10
# 11                         E2           H8, H6, H10

# %% [markdown]
# #### 5.3.2. Rename columns

# %%
df_elm.rename(columns={'Earthly Branchin anyPillar': 'branch', 'Hidden Heavenly Stems': 'all_stems'}, inplace=True)
df_elm.columns
# Out:
# Index(['branch', 'all_stems'], dtype='object')

# %% [markdown]
# #### 5.3.3. Define main and hidden stems in branch

# %%
#create a new column indicating main stem in branch
def main_elm(x):
    y = x.split(', ')
    z = round(0.5*len(y))
    return y[z-1]

#create a new column indicating hidden stems in branch
def hidden_elm(x):
    y = x.split(', ')
    if len(y) == 1:
        z = np.nan
    elif len(y)==3:
        z = y[0] + ', ' + y[2]
    elif len(y)==2:
        z = y[1]
    return z

df_elm['main_stem'] = df_elm['all_stems'].apply(lambda x: main_elm(x))
df_elm['hidden_stems'] = df_elm['all_stems'].apply(lambda x: hidden_elm(x))
df_elm
# Out:
#    branch    all_stems main_stem hidden_stems
# 0      E3   H5, H1, H3        H1       H5, H3
# 1      E4           H2        H2          NaN
# 2      E5  H10, H5, H2        H5      H10, H2
# 3      E6   H7, H3, H5        H3       H7, H5
# 4      E7       H4, H6        H4           H6
# 5      E8   H4, H6, H2        H6       H4, H2
# 6      E9   H5, H7, H9        H7       H5, H9
# 7     E10           H8        H8          NaN
# 8     E11   H4, H5, H8        H5       H4, H8
# 9     E12       H9, H1        H9           H1
# 10     E1          H10       H10          NaN
# 11     E2  H8, H6, H10        H6      H8, H10

# %% [markdown]
# ### 5.4. Scrape earthly branch association table

# %% [markdown]
# #### 5.4.1. Send http request, receive html responses and convert html to dataframe

# %%
# %%time
url_eb_asc = 'https://en.wikibooks.org/wiki/Ba_Zi/Earthly_Branches'
html = requests.get(url_eb_asc, timeout = 5, verify = True)
df_eb_asc_scraped = pd.read_html(html.text)
# Out:
# Wall time: 39.2 ms

# %%
df_eb_asc_scraped
# Out:
# [    S/N    Time(时辰) Notation Chinese Pinyin  \
#  0     1  11pm - 1am      EB1             zǐ
#  1     2   1am - 3am      EB2           chǒu
#  2     3   3am - 5am      EB3            yín
#  3     4   5am - 7am      EB4            mǎo
#  4     5   7am - 9am      EB5           chén
#  5     6  9am - 11am      EB6             sì
#  6     7  11am - 1pm      EB7             wǔ
#  7     8   1pm - 3pm      EB8            wèi
#  8     9   3pm - 5pm      EB9           shēn
#  9    10   5pm - 7pm     EB10            yǒu
#  10   11    7pm -9pm     EB11             xū
#  11   12  9pm - 11pm     EB12            hài
#
#     Earthly Branch in Simplified Chinese(地支) 12 Animal Mnemonics(十二支)  \
#  0                                         子                      Rat
#  1                                         丑                       Ox
#  2                                         寅                    Tiger
#  3                                         卯                   Rabbit
#  4                                         辰                   Dragon
#  5                                         巳                    Snake
#  6                                         午                    Horse
#  7                                         未                     Goat
#  8                                         申                   Monkey
#  9                                         酉                  Rooster
#  10                                        戌                      Dog
#  11                                        亥                      Pig
#
#     Yin/Yang(阴阳) Five Elements(五行)
#  0          Yang             Water
#  1           Yin             Earth
#  2          Yang              Wood
#  3           Yin              Wood
#  4          Yang             Earth
#  5           Yin              Fire
#  6          Yang              Fire
#  7           Yin             Earth
#  8          Yang             Metal
#  9           Yin             Metal
#  10         Yang             Earth
#  11          Yin             Water  ,
#          0                          1                                  2  \
#  0   Row 1       SeasonalCombinations  combination(E3,E4,E5){Spring}Wood
#  1   Row 2         Three Combinations         combination(E12,E4,E8)Wood
#  2   Row 3    Front Half Combinations            combination(E12,E4)Wood
#  3   Row 4     Rear Half Combinations             combination(E4,E8)Wood
#  4   Row 5           Six Combinations            combination(E1,E2)Earth
#  5   Row 6  Three Persecuting Clashes                    clash(E3,E6,E9)
#  6   Row 7                Six Clashes                       clash(E1,E7)
#  7   Row 8                    Clashes      clash(E1,E4)Ingratitude Clash
#  8   Row 9              Related Clash                      clash(E1,E10)
#  9  Row 10           Conflicted Clash                       clash(E1,E8)
#
#                                     3                                     4  \
#  0  combination(E6,E7,E8){Summer}Fire  combination(E9,E10,E11){Autumn}Metal
#  1         combination(E3,E7,E11)Fire           combination(E6,E10,E2)Metal
#  2             combination(E3,E7)Fire              combination(E6,E10)Metal
#  3            combination(E7,E11)Fire              combination(E10,E2)Metal
#  4            combination(E3,E12)Wood               combination(E4,E11)Fire
#  5                   clash(E2,E8,E11)             Partial Persecuting Clash
#  6                       clash(E2,E8)                          clash(E3,E9)
#  7             clash(E5,E5)Self Clash                clash(E7,E7)Self Clash
#  8                      clash(E3,E12)                          clash(E2,E5)
#  9                       clash(E2,E7)                          clash(E3,E6)
#
#                                        5  \
#  0   combination(E12,E1,E2){Winter}Water
#  1            combination(E9,E1,E5)Water
#  2               combination(E9,E1)Water
#  3               combination(E1,E5)Water
#  4              combination(E5,E10)Metal
#  5  clash(E3,E6)clash(E6,E9)clash(E9,E3)
#  6                         clash(E4,E10)
#  7              clash(E10,E10)Self Clash
#  8                          clash(E4,E7)
#  9                          clash(E4,E5)
#
#                                          6                       7
#  0                                     NaN                     NaN
#  1                                     NaN                     NaN
#  2                                     NaN                     NaN
#  3                                     NaN                     NaN
#  4                 combination(E6,E9)Water  combination(E7,E8)Fire
#  5  clash(E2,E11)clash(E8,E2)clash(E11,E8)                     NaN
#  6                           clash(E5,E11)           clash(E6,E12)
#  7                clash(E12,E12)Self Clash                     NaN
#  8                            clash(E6,E9)           clash(E8,E11)
#  9                           clash(E9,E12)          clash(E10,E11)  ,
#     EarthlyBranch HiddenStem 1 HiddenStem 2 HiddenStem 3
#  0         E1 Rat    H10-Water          NaN          NaN
#  1          E2 Ox     H8-Metal     H6-Earth    H10-Water
#  2       E3 Tiger     H5+Earth      H1+Wood      H3+Fire
#  3      E4 Rabbit      H2-Wood          NaN          NaN
#  4      E5 Dragon    H10-Water     H5+Earth      H2-Wood
#  5       E6 Snake     H7+Metal      H3+Fire     H5+Earth
#  6       E7 Horse      H4-Fire     H6-Earth          NaN
#  7        E8 Goat      H4-Fire     H6-Earth      H2-Wood
#  8      E9 Monkey     H5+Earth     H7+Metal     H9+Water
#  9    E10 Rooster     H8-Metal          NaN          NaN
#  10       E11 Dog      H4-Fire     H5+Earth     H8-Metal
#  11       E12 Pig     H9+Water      H1+Wood          NaN]

# %%
df_eb_asc = df_eb_asc_scraped[0]
df_eb_asc
# Out:
#     S/N    Time(时辰) Notation Chinese Pinyin  \
# 0     1  11pm - 1am      EB1             zǐ
# 1     2   1am - 3am      EB2           chǒu
# 2     3   3am - 5am      EB3            yín
# 3     4   5am - 7am      EB4            mǎo
# 4     5   7am - 9am      EB5           chén
# 5     6  9am - 11am      EB6             sì
# 6     7  11am - 1pm      EB7             wǔ
# 7     8   1pm - 3pm      EB8            wèi
# 8     9   3pm - 5pm      EB9           shēn
# 9    10   5pm - 7pm     EB10            yǒu
# 10   11    7pm -9pm     EB11             xū
# 11   12  9pm - 11pm     EB12            hài
#
#    Earthly Branch in Simplified Chinese(地支) 12 Animal Mnemonics(十二支)  \
# 0                                         子                      Rat
# 1                                         丑                       Ox
# 2                                         寅                    Tiger
# 3                                         卯                   Rabbit
# 4                                         辰                   Dragon
# 5                                         巳                    Snake
# 6                                         午                    Horse
# 7                                         未                     Goat
# 8                                         申                   Monkey
# 9                                         酉                  Rooster
# 10                                        戌                      Dog
# 11                                        亥                      Pig
#
#    Yin/Yang(阴阳) Five Elements(五行)
# 0          Yang             Water
# 1           Yin             Earth
# 2          Yang              Wood
# 3           Yin              Wood
# 4          Yang             Earth
# 5           Yin              Fire
# 6          Yang              Fire
# 7           Yin             Earth
# 8          Yang             Metal
# 9           Yin             Metal
# 10         Yang             Earth
# 11          Yin             Water

# %% [markdown]
# #### 5.4.2. Drop columns

# %%
df_eb_asc.drop(columns = ['S/N', 'Chinese Pinyin'], inplace = True)
df_eb_asc
# Out:
#       Time(时辰) Notation Earthly Branch in Simplified Chinese(地支)  \
# 0   11pm - 1am      EB1                                        子
# 1    1am - 3am      EB2                                        丑
# 2    3am - 5am      EB3                                        寅
# 3    5am - 7am      EB4                                        卯
# 4    7am - 9am      EB5                                        辰
# 5   9am - 11am      EB6                                        巳
# 6   11am - 1pm      EB7                                        午
# 7    1pm - 3pm      EB8                                        未
# 8    3pm - 5pm      EB9                                        申
# 9    5pm - 7pm     EB10                                        酉
# 10    7pm -9pm     EB11                                        戌
# 11  9pm - 11pm     EB12                                        亥
#
#    12 Animal Mnemonics(十二支) Yin/Yang(阴阳) Five Elements(五行)
# 0                       Rat         Yang             Water
# 1                        Ox          Yin             Earth
# 2                     Tiger         Yang              Wood
# 3                    Rabbit          Yin              Wood
# 4                    Dragon         Yang             Earth
# 5                     Snake          Yin              Fire
# 6                     Horse         Yang              Fire
# 7                      Goat          Yin             Earth
# 8                    Monkey         Yang             Metal
# 9                   Rooster          Yin             Metal
# 10                      Dog         Yang             Earth
# 11                      Pig          Yin             Water

# %% [markdown]
# #### 5.4.3. Rename columns

# %%
df_eb_asc.rename(columns = {
    'Time(时辰)':'time',
    'Notation': 'branch',
    'Earthly Branch in Simplified Chinese(地支)': 'chinese',
    '12 Animal Mnemonics(十二支)': 'animal',
    'Yin/Yang(阴阳)':'ying_yang',
    'Five Elements(五行)': 'element'
}, inplace = True)

df_eb_asc
# Out:
#           time branch chinese   animal ying_yang element
# 0   11pm - 1am    EB1       子      Rat      Yang   Water
# 1    1am - 3am    EB2       丑       Ox       Yin   Earth
# 2    3am - 5am    EB3       寅    Tiger      Yang    Wood
# 3    5am - 7am    EB4       卯   Rabbit       Yin    Wood
# 4    7am - 9am    EB5       辰   Dragon      Yang   Earth
# 5   9am - 11am    EB6       巳    Snake       Yin    Fire
# 6   11am - 1pm    EB7       午    Horse      Yang    Fire
# 7    1pm - 3pm    EB8       未     Goat       Yin   Earth
# 8    3pm - 5pm    EB9       申   Monkey      Yang   Metal
# 9    5pm - 7pm   EB10       酉  Rooster       Yin   Metal
# 10    7pm -9pm   EB11       戌      Dog      Yang   Earth
# 11  9pm - 11pm   EB12       亥      Pig       Yin   Water

# %% [markdown]
# #### 5.4.4. Standardise branch notation

# %%
df_eb_asc['branch'] = df_eb_asc['branch'].apply(lambda x: re.sub(r'EB','E', x))
df_eb_asc
# Out:
#           time branch chinese   animal ying_yang element
# 0   11pm - 1am     E1       子      Rat      Yang   Water
# 1    1am - 3am     E2       丑       Ox       Yin   Earth
# 2    3am - 5am     E3       寅    Tiger      Yang    Wood
# 3    5am - 7am     E4       卯   Rabbit       Yin    Wood
# 4    7am - 9am     E5       辰   Dragon      Yang   Earth
# 5   9am - 11am     E6       巳    Snake       Yin    Fire
# 6   11am - 1pm     E7       午    Horse      Yang    Fire
# 7    1pm - 3pm     E8       未     Goat       Yin   Earth
# 8    3pm - 5pm     E9       申   Monkey      Yang   Metal
# 9    5pm - 7pm    E10       酉  Rooster       Yin   Metal
# 10    7pm -9pm    E11       戌      Dog      Yang   Earth
# 11  9pm - 11pm    E12       亥      Pig       Yin   Water

# %% [markdown]
# #### 5.4.5. Merge with earlier branch-related table

# %%
left_join = pd.merge(df_elm, 
                      df_eb_asc, 
                      on ='branch', 
                      how ='left')
df_branch = left_join
df_branch.head(15)
# Out:
#    branch    all_stems main_stem hidden_stems        time chinese   animal  \
# 0      E3   H5, H1, H3        H1       H5, H3   3am - 5am       寅    Tiger
# 1      E4           H2        H2          NaN   5am - 7am       卯   Rabbit
# 2      E5  H10, H5, H2        H5      H10, H2   7am - 9am       辰   Dragon
# 3      E6   H7, H3, H5        H3       H7, H5  9am - 11am       巳    Snake
# 4      E7       H4, H6        H4           H6  11am - 1pm       午    Horse
# 5      E8   H4, H6, H2        H6       H4, H2   1pm - 3pm       未     Goat
# 6      E9   H5, H7, H9        H7       H5, H9   3pm - 5pm       申   Monkey
# 7     E10           H8        H8          NaN   5pm - 7pm       酉  Rooster
# 8     E11   H4, H5, H8        H5       H4, H8    7pm -9pm       戌      Dog
# 9     E12       H9, H1        H9           H1  9pm - 11pm       亥      Pig
# 10     E1          H10       H10          NaN  11pm - 1am       子      Rat
# 11     E2  H8, H6, H10        H6      H8, H10   1am - 3am       丑       Ox
#
#    ying_yang element
# 0       Yang    Wood
# 1        Yin    Wood
# 2       Yang   Earth
# 3        Yin    Fire
# 4       Yang    Fire
# 5        Yin   Earth
# 6       Yang   Metal
# 7        Yin   Metal
# 8       Yang   Earth
# 9        Yin   Water
# 10      Yang   Water
# 11       Yin   Earth

# %% [markdown]
# ### 5.5. Scrape heavenly stem association table

# %% [markdown]
# #### 5.5.1. Send http request, receive html responses and convert html to dataframe

# %%
# %%time
url_hs_asc = 'https://en.wikibooks.org/wiki/Ba_Zi/Heavenly_Stems'
html = requests.get(url_hs_asc, timeout = 5, verify = True)
df_hs_asc_scraped = pd.read_html(html.text)
# Out:
# Wall time: 36 ms

# %%
df_hs_asc_scraped
# Out:
# [   S/N Heavenly Stem(天干) Notation Chinese Pinyin Simplified Chinese  \
#  0    1               Jia      HS1            jiǎ                  甲
#  1    2                Yi      HS2             yǐ                  乙
#  2    3              Bing      HS3           bǐng                  丙
#  3    4              Ding      HS4           dīng                  丁
#  4    5                Wu      HS5             wù                  戊
#  5    6                Ji      HS6             jǐ                  己
#  6    7              Geng      HS7           gēng                  庚
#  7    8               Xin      HS8            xīn                  辛
#  8    9               Ren      HS9            rén                  壬
#  9   10               Gui     HS10            guǐ                  癸
#
#    Yin/Yang(阴阳) Five Elements(五行)   Zang/Fu(organ)
#  0         Yang              Wood     Gall Bladder
#  1          Yin              Wood            Liver
#  2         Yang              Fire  Small Intestine
#  3          Yin              Fire            Heart
#  4         Yang             Earth          Stomach
#  5          Yin             Earth           Spleen
#  6         Yang             Metal  Large Intestine
#  7          Yin             Metal             Lung
#  8         Yang             Water  Urinary Bladder
#  9          Yin             Water           Kidney  ,
#      HS              H1              H2              H3              H4  \
#  0   H1             NaN             NaN             NaN             NaN
#  1   H2             NaN             NaN             NaN             NaN
#  2   H3             NaN             NaN             NaN             NaN
#  3   H4             NaN             NaN             NaN             NaN
#  4   H5    ClashElement             NaN             NaN             NaN
#  5   H6       5ComEarth    ClashElement             NaN             NaN
#  6   H7  ClashDirection       5ComMetal    ClashElement             NaN
#  7   H8             NaN  ClashDirection       5ComWater    ClashElement
#  8   H9             NaN             NaN  ClashDirection        5ComWood
#  9  H10             NaN             NaN             NaN  ClashDirection
#
#               H5            H6              H7              H8              H9  \
#  0  ClashElement     5ComEarth  ClashDirection             NaN             NaN
#  1           NaN  ClashElement       5ComMetal  ClashDirection             NaN
#  2           NaN           NaN    ClashElement       5ComWater  ClashDirection
#  3           NaN           NaN             NaN    ClashElement        5ComWood
#  4           NaN           NaN             NaN             NaN    ClashElement
#  5           NaN           NaN             NaN             NaN             NaN
#  6           NaN           NaN             NaN             NaN             NaN
#  7           NaN           NaN             NaN             NaN             NaN
#  8  ClashElement           NaN             NaN             NaN             NaN
#  9      5ComFire  ClashElement             NaN             NaN             NaN
#
#                H10
#  0             NaN
#  1             NaN
#  2             NaN
#  3  ClashDirection
#  4        5ComFire
#  5    ClashElement
#  6             NaN
#  7             NaN
#  8             NaN
#  9             NaN  ]

# %%
df_stem = df_hs_asc_scraped[0]
df_stem
# Out:
#    S/N Heavenly Stem(天干) Notation Chinese Pinyin Simplified Chinese  \
# 0    1               Jia      HS1            jiǎ                  甲
# 1    2                Yi      HS2             yǐ                  乙
# 2    3              Bing      HS3           bǐng                  丙
# 3    4              Ding      HS4           dīng                  丁
# 4    5                Wu      HS5             wù                  戊
# 5    6                Ji      HS6             jǐ                  己
# 6    7              Geng      HS7           gēng                  庚
# 7    8               Xin      HS8            xīn                  辛
# 8    9               Ren      HS9            rén                  壬
# 9   10               Gui     HS10            guǐ                  癸
#
#   Yin/Yang(阴阳) Five Elements(五行)   Zang/Fu(organ)
# 0         Yang              Wood     Gall Bladder
# 1          Yin              Wood            Liver
# 2         Yang              Fire  Small Intestine
# 3          Yin              Fire            Heart
# 4         Yang             Earth          Stomach
# 5          Yin             Earth           Spleen
# 6         Yang             Metal  Large Intestine
# 7          Yin             Metal             Lung
# 8         Yang             Water  Urinary Bladder
# 9          Yin             Water           Kidney

# %% [markdown]
# #### 5.5.2. Drop columns

# %%
df_stem = df_stem.drop(columns = ['S/N', 'Chinese Pinyin'])
df_stem
# Out:
#   Heavenly Stem(天干) Notation Simplified Chinese Yin/Yang(阴阳)  \
# 0               Jia      HS1                  甲         Yang
# 1                Yi      HS2                  乙          Yin
# 2              Bing      HS3                  丙         Yang
# 3              Ding      HS4                  丁          Yin
# 4                Wu      HS5                  戊         Yang
# 5                Ji      HS6                  己          Yin
# 6              Geng      HS7                  庚         Yang
# 7               Xin      HS8                  辛          Yin
# 8               Ren      HS9                  壬         Yang
# 9               Gui     HS10                  癸          Yin
#
#   Five Elements(五行)   Zang/Fu(organ)
# 0              Wood     Gall Bladder
# 1              Wood            Liver
# 2              Fire  Small Intestine
# 3              Fire            Heart
# 4             Earth          Stomach
# 5             Earth           Spleen
# 6             Metal  Large Intestine
# 7             Metal             Lung
# 8             Water  Urinary Bladder
# 9             Water           Kidney

# %% [markdown]
# #### 5.5.3. Rename columns

# %%
df_stem = df_stem.rename(columns = {
    'Heavenly Stem(天干)':'name',
    'Notation': 'stem',
    'Simplified Chinese': 'chinese',
    'Zang/Fu(organ)': 'organ',
    'Yin/Yang(阴阳)':'ying_yang',
    'Five Elements(五行)': 'element'
})

df_stem
# Out:
#    name  stem chinese ying_yang element            organ
# 0   Jia   HS1       甲      Yang    Wood     Gall Bladder
# 1    Yi   HS2       乙       Yin    Wood            Liver
# 2  Bing   HS3       丙      Yang    Fire  Small Intestine
# 3  Ding   HS4       丁       Yin    Fire            Heart
# 4    Wu   HS5       戊      Yang   Earth          Stomach
# 5    Ji   HS6       己       Yin   Earth           Spleen
# 6  Geng   HS7       庚      Yang   Metal  Large Intestine
# 7   Xin   HS8       辛       Yin   Metal             Lung
# 8   Ren   HS9       壬      Yang   Water  Urinary Bladder
# 9   Gui  HS10       癸       Yin   Water           Kidney

# %% [markdown]
# #### 5.5.4. Standardise stem notation

# %%
df_stem['stem'] = df_stem['stem'].apply(lambda x: re.sub(r'HS','H', x))
df_stem
# Out:
#    name stem chinese ying_yang element            organ
# 0   Jia   H1       甲      Yang    Wood     Gall Bladder
# 1    Yi   H2       乙       Yin    Wood            Liver
# 2  Bing   H3       丙      Yang    Fire  Small Intestine
# 3  Ding   H4       丁       Yin    Fire            Heart
# 4    Wu   H5       戊      Yang   Earth          Stomach
# 5    Ji   H6       己       Yin   Earth           Spleen
# 6  Geng   H7       庚      Yang   Metal  Large Intestine
# 7   Xin   H8       辛       Yin   Metal             Lung
# 8   Ren   H9       壬      Yang   Water  Urinary Bladder
# 9   Gui  H10       癸       Yin   Water           Kidney

# %% [markdown]
# ## 6. Export cleaned dataframes to csv

# %%
df_birth.to_csv('data/df_birth.csv', index = False)
df_hour.to_csv('data/df_hour.csv', index = False)
df_branch.to_csv('data/df_branch.csv', index = False)
df_stem.to_csv('data/df_stem.csv', index = False)

# %% [markdown]
# End of Part 1 - We will use the csv files to create a SQL database and run queries using SQL language in PostgreSQL.
